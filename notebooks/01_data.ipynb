# %%
import pandas as pd 

# col names from UCI documentation
cols = [ 
    'age', 'workclass', 'fnlwgt', 'education', education-num', 'marital-status',
    'occupation', 'relationship', 'race', 'sex']

# load data
file_path = 'data/raw/adult.data'
